# %%
# %load_ext sql

# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
import csv
import pandas as pd

# %%
Uganda = pd.read_csv('/Uganda_Karamoja_Subcounty_Crop_Yield_Population.csv')

# %%
# %sql DROP TABLE if EXISTS Uganda;
# %sql PERSIST Uganda;
# Out:
#  * sqlite://
# Done.
#  * sqlite://
# 'Persisted uganda'

# %%
# %%sql
# SELECT * FROM Uganda LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(0, 263, 'KACHERI', 'KOTIDO', 17244, 1067176155, 'Y', 354.20741069999997, 1137.467019, 7023.533691, 6434.342449, 528.1242294, 2279091.779, 600723.8929),
#  (1, 264, 'KOTIDO', 'KOTIDO', 52771, 597575188, 'Y', 367.89052319999996, 1162.9966869999998, 13587.990759999999, 12455.59264, 824.7670809, 4582294.492, 959201.3825),
#  (2, 265, 'KOTIDO TOWN COUNCIL', 'KOTIDO', 27389, 23972401, 'Y', 369.3141771, 1167.005832, 1656.5318550000002, 1520.322052, 8.561643817, 561476.4874, 9991.488268000001),
#  (3, 266, 'NAKAPERIMORU', 'KOTIDO', 38775, 419111591, 'Y', 283.3245689, 852.3665784, 7087.823334000001, 6761.488901000001, 45.72171184, 1915695.928, 38971.65908),
#  (4, 267, 'PANYANGARA', 'KOTIDO', 65704, 880955930, 'Y', 373.8369255, 1283.859882, 10398.24939, 10111.198129999999, 172.6119139, 3779939.224, 221609.5114)]

# %%
# Sort the list of districts by total crop area(descending)
# %%sql 
SELECT * FROM Uganda ORDER BY Crop_Area_Ha DESC
# Out:
#  * sqlite://
# Done.
# [(1, 264, 'KOTIDO', 'KOTIDO', 52771, 597575188, 'Y', 367.89052319999996, 1162.9966869999998, 13587.990759999999, 12455.59264, 824.7670809, 4582294.492, 959201.3825),
#  (5, 268, 'RENGEN', 'KOTIDO', 41273, 652744859, 'Y', 271.18584310000006, 1047.180128, 13278.52043, 12964.49973, 171.5857036, 3515788.789, 179681.139),
#  (4, 267, 'PANYANGARA', 'KOTIDO', 65704, 880955930, 'Y', 373.8369255, 1283.859882, 10398.24939, 10111.198129999999, 172.6119139, 3779939.224, 221609.5114),
#  (3, 266, 'NAKAPERIMORU', 'KOTIDO', 38775, 419111591, 'Y', 283.3245689, 852.3665784, 7087.823334000001, 6761.488901000001, 45.72171184, 1915695.928, 38971.65908),
#  (0, 263, 'KACHERI', 'KOTIDO', 17244, 1067176155, 'Y', 354.20741069999997, 1137.467019, 7023.533691, 6434.342449, 528.1242294, 2279091.779, 600723.8929),
#  (12, 597, 'KATHILE', 'KAABONG', 56870, 228457417, 'Y', 312.2786152, 1125.685462, 6890.699234000001, 5997.222911, 867.8731713, 1872804.465, 976952.2116),
# ...

# %%
# Sub-counties from Moroto District
# %%sql
SELECT COUNT(DISTRICT_NAME)
FROM Uganda
WHERE MOROTO;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) no such column: MOROTO
# [SQL: SELECT COUNT(DISTRICT_NAME)
# FROM Uganda
# WHERE MOROTO;]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Total maize production
# %%sql
SELECT SUM()
