# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from __future__ import division
# %matplotlib inline
from __future__ import print_function

# let's import the linerar regression model
from sklearn.linear_model import LinearRegression

# %%
# let's now load our house prices dataset
data = pd.read_csv('house_prices.csv')
data.head()
# Out:
#    LotArea  SalePrice
# 0     8450     208500
# 1     9600     181500
# 2    11250     223500
# 3     9550     140000
# 4    14260     250000

# %%
# let's plot our data 
import matplotlib.pyplot as plt
plt.scatter(data['LotArea'], data['SalePrice'])
plt.title('NYC House pricing')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### From the above plot, we can see an upward trend in the House prices as the area of the houses increases. We can say that the price of the house is directly propotional to the area occupied by the house.

# %%
# Now let's try predicting the price of a house whose area is 1400 sq feet
plt.scatter(data['LotArea'], data['SalePrice'])
plt.axvline(x=14000,linewidth='1',color='r')
plt.title('NYC House pricing')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
# let's try plotting a line of best fit
import matplotlib.pyplot as plt
plt.scatter(data.LotArea, data.SalePrice)
plt.plot(data.LotArea, 30000 + 15*data.LotArea, "r-")
plt.title('NYC House pricing')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### We can also use this to predict the price of the house

# %%
X = data.LotArea[:,np.newaxis]  # Reshape
y = data.SalePrice

# %%
# Predicting the Test set results
y_pred = regressor.predict(X)

# %%
# let's fit the linear regression to the training set
regressor = LinearRegression()
regressor.fit(X,y)
# Out:
# LinearRegression()

# %%
 # Train Part
plt.scatter(X, y)
plt.plot(X, y_pred, "r-")
plt.title('Housing Price ')
plt.xlabel('Area')
plt.ylabel('Price')
plt.axvline(x=14000,c='g');

# %% [markdown]
# #### We can see that for a house of area 14000 sq, we need to pay 200000 - 225000
