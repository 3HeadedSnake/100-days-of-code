# %% [markdown]
# # Logistic Regression

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

# %matplotlib inline

X, y = make_classification(n_samples=10, n_features=1, n_informative=1, n_redundant=0 , n_clusters_per_class=1, flip_y=0, random_state=7)

# %%
# Logistic Regression Model
clf = LogisticRegression()

X, Y = make_classification(n_samples=10, n_features=1, n_informative=1, n_redundant=0, n_clusters_per_class=1, flip_y=0, random_state=7)
clf.fit(X, y)
# Out:
# LogisticRegression()

# %%
# Let's now plot the the 
plt.figure(figsize=(10,6))
plt.scatter(X, y, c='r', marker='x')
xt = np.linspace(-3, 3, 1000).reshape(1000,1)
yt = clf.predict(xt)
plt.plot(xt, yt)
plt.xlabel('Feature')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %% [markdown]
# ### We can see how Logistic Regression handles the classes well, now we'll try adding outliers.

# %%
# Let's now create the features.
obs = 20
X = np.vstack([X, obs])
y = np.append(y, 1)

clf.fit(X, y) # Fits the Logistic Regression Model.
# Out:
# LogisticRegression()

# %%
# Now let's plot after adding outliers
plt.figure(figsize=(10,6))
plt.scatter(X, y, c='r', marker='x')
xt = np.linspace(-5, 25, 1000).reshape(1000,1)
yt = clf.predict(xt)
plt.plot(xt, yt)
plt.xlabel('Feature')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %% [markdown]
# ### Logistic Regression still separates the classes well. For this reason, Logistic Regression is appropriate for Classification problems.
